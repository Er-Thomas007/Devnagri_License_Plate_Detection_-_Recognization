# %%
# !pip install ultralytics roboflow

# %%
import torch
from roboflow import Roboflow

# Set up Roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="JMSwOdLey3YhDa7510SX")
project = rf.workspace("lprsystem-tm1rt").project("lpr-fjgjq")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.25, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to LPR-2 in yolov8:: 100%|██████████| 774/774 [00:00<00:00, 8673.60it/s]

# %%
from ultralytics import YOLO

# Load YOLOv8 model (you can also specify a pre-trained weight file if you have one)
model = YOLO('yolov8n.yaml')  # 'yolov8n.yaml' for a new model; replace with the path to a pre-trained model if needed

# Train the model
model.train(data='/content/LPR-2/data.yaml', epochs=10, imgsz=640, batch=16)
# Out:
# Ultralytics YOLOv8.2.25 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Evaluate the model
metrics = model.val()
print(metrics)
# Out:
# Ultralytics YOLOv8.2.25 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/LPR-2/valid/labels.cache... 10 images, 0 backgrounds, 0 corrupt: 100%|██████████| 10/10 [00:00<?, ?it/s]
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.46it/s]
#                    all         10         11       0.98      0.818      0.877      0.364
# Speed: 0.3ms preprocess, 32.1ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to runs/detect/train2
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# ...

# %%
# Perform inference on an image
results = model('/content/IMG_20240528_171753.jpg')  # Replace with the path to your image

# Access the first result from the list and display it
result = results[0]
result.show()
# Out:
# image 1/1 /content/IMG_20240528_171753.jpg: 640x480 2 vehicles, 7.1ms
# Speed: 3.4ms preprocess, 7.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)

# %%
import subprocess

# Install necessary libraries
subprocess.run(['pip', 'install', 'opencv-python-headless', 'matplotlib', 'ultralytics'])

# Import libraries
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow
from ultralytics import YOLO

# Load YOLOv8 model (assuming you've already trained it or using a pretrained model)
model = YOLO('/content/best.pt')  # Replace 'yolov8n.pt' with your trained model path if necessary

# Perform inference on an image
results = model('/content/4 wheeler 1.jpg')  # Replace with the path to your image

# Access the first result from the list
result = results[0]

# Convert the image to a format that can be displayed
img_with_detections = result.plot()

# Display the image with detections
cv2_imshow(img_with_detections)
plt.show()
# Out:
# image 1/1 /content/4 wheeler 1.jpg: 448x640 1 Four_Wheeler, 1 License_Plate, 156.8ms
# Speed: 2.9ms preprocess, 156.8ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=1024x683>

# %%
import subprocess

# Install necessary libraries
subprocess.run(['pip', 'install', 'opencv-python-headless', 'matplotlib', 'ultralytics'])

# Import libraries
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow
from ultralytics import YOLO

# Load YOLOv8 model (assuming you've already trained it or using a pretrained model)
model = YOLO('/content/best.pt')  # Replace 'best.pt' with your trained model path if necessary

# Function to process an image
def process_image(image_path):
    # Perform inference on the image
    results = model(image_path)

    # Access the first result from the list
    result = results[0]

    # Convert the image to a format that can be displayed
    img_with_detections = result.plot()

    # Display the image with detections
    cv2_imshow(img_with_detections)
    plt.show()

# Function to process video
def process_video(input_video_path, output_video_path):
    # Open the video file
    cap = cv2.VideoCapture(input_video_path)

    # Get the video frame width, height, and FPS
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Define the codec and create a VideoWriter object to save the output video
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # You can change the codec as needed
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Perform inference on the current frame
        results = model(frame)

        # Access the first result from the list
        result = results[0]

        # Convert the image to a format that can be displayed
        img_with_detections = result.plot()

        # Write the frame with detections to the output video
        out.write(img_with_detections)

    # Release the video capture and writer objects
    cap.release()
    out.release()

    # Display the saved output video path
    print(f"Output video saved at: {output_video_path}")

# Path to the input image or video file
input_image_path = '/content/_dsc6075-2.jpg'  # Replace with the path to your image
input_video_path = '/content/2103099-uhd_3840_2160_30fps.mp4'  # Replace with the path to your input video
output_video_path = '/content/output_video.mp4'  # Replace with the desired output path for the processed video

# Choose which type of processing to run
process_type = 'video'  # Set to 'video' for processing video, 'image' for processing image

if process_type == 'image':
    process_image(input_image_path)
elif process_type == 'video':
    process_video(input_video_path, output_video_path)

# If in a notebook environment, display the output video file
from IPython.display import HTML
from base64 import b64encode

def show_video(video_path, video_width):
    video_file = open(video_path, "rb").read()
    video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
    return HTML(f"""<video width="{video_width}" controls>
                        <source src="{video_url}" type="video/mp4">
                    </video>""")

# Display the output video (if processing a video)
if process_type == 'video':
    display(show_video(output_video_path, 640))  # Adjust width as needed
# Out:
# 0: 384x640 2 Four_Wheelers, 2 License_Plates, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Four_Wheelers, 1 License_Plate, 10.3ms
# Speed: 3.2ms preprocess, 10.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Four_Wheelers, 1 License_Plate, 10.1ms
# Speed: 3.2ms preprocess, 10.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Four_Wheelers, 2 License_Plates, 10.7ms
# Speed: 3.7ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Four_Wheelers, 2 License_Plates, 12.2ms
# Speed: 3.2ms preprocess, 12.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Four_Wheelers, 2 License_Plates, 10.3ms
# Speed: 3.2ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Four_Wheelers, 1 License_Plate, 9.9ms
# ...
